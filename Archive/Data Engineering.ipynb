# %%
import pandas as pd
import numpy as np
import glob
import os
import pickle

# %%
dataCheck = pd.read_csv('Data/TestSet/2010-12-greater-manchester-street.csv')

# %%
dataCheck.head()
# Out:
#    Crime ID    Month                Reported by               Falls within  \
# 0       NaN  2010-12  Greater Manchester Police  Greater Manchester Police
# 1       NaN  2010-12  Greater Manchester Police  Greater Manchester Police
# 2       NaN  2010-12  Greater Manchester Police  Greater Manchester Police
# 3       NaN  2010-12  Greater Manchester Police  Greater Manchester Police
# 4       NaN  2010-12  Greater Manchester Police  Greater Manchester Police
#
#    Longitude   Latitude                   Location  LSOA code  \
# 0  -2.392346  53.634640    On or near Birches Road  E01032485
# 1  -2.444807  53.611509    On or near Belmont Road  E01004768
# 2  -2.444807  53.611509    On or near Belmont Road  E01004768
# 3  -2.440493  53.612388  On or near Threlkeld Road  E01004768
# 4  -2.444807  53.611509    On or near Belmont Road  E01004768
#
#                     LSOA name             Crime type  Last outcome category  \
# ...

# %%
pathTest = r'Data/TestSet'
lstAllFiles = glob.glob(pathTest + '/*.csv')
lstAllFiles
# Out:
# ['Data/TestSet\\2010-12-greater-manchester-street.csv',
#  'Data/TestSet\\2011-01-greater-manchester-street.csv',
#  'Data/TestSet\\2011-02-greater-manchester-street.csv',
#  'Data/TestSet\\2011-03-greater-manchester-street.csv',
#  'Data/TestSet\\2011-04-greater-manchester-street.csv',
#  'Data/TestSet\\2011-05-greater-manchester-street.csv',
#  'Data/TestSet\\2011-06-greater-manchester-street.csv',
#  'Data/TestSet\\2011-07-greater-manchester-street.csv']

# %%
# x = pd.read_csv('Data/TestSet/2011-01-greater-manchester-street.csv')
# z = pd.read_csv('Data/TestSet/2011-02-greater-manchester-street.csv')
# x.head()

# %%
path = r'Data/Greater Manchester/street'
all_files = glob.glob(path + "/*.csv")
# all_files

# %%
# df_str.info()

# %%
# frame[frame['Falls within'] !=  'Greater Manchester Police']

# %%
def concat_files_to_df(lstFiles):
    '''takes a lst of filenames, will transform these files into one dataframe
    note: it will only work with csv files with same columns, or pandas will break'''
    
    lst = []
    
    for filename in lstFiles:
        df = pd.read_csv(filename, index_col=None, header=0)
        lst.append(df)
        
    dataframe = pd.concat(lst, axis=0, ignore_index=True)
    return dataframe

# %%
x = concat_files_to_df(lstAllFiles)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240818 entries, 0 to 240817
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Crime ID               71055 non-null   object
#  1   Month                  240818 non-null  object
#  2   Reported by            240818 non-null  object
#  3   Falls within           240818 non-null  object
#  4   Longitude              240818 non-null  float64
#  5   Latitude               240818 non-null  float64
#  6   Location               240818 non-null  object
#  7   LSOA code              240818 non-null  object
#  8   LSOA name              240818 non-null  object
#  9   Crime type             240818 non-null  object
#  10  Last outcome category  0 non-null       float64
#  11  Context                4884 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 22.0+ MB

# %%
allData = concat_files_to_df(all_files)

# %%
allData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3034429 entries, 0 to 3034428
# Data columns (total 12 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Crime ID               object
#  1   Month                  object
#  2   Reported by            object
#  3   Falls within           object
#  4   Longitude              float64
#  5   Latitude               float64
#  6   Location               object
#  7   LSOA code              object
#  8   LSOA name              object
#  9   Crime type             object
#  10  Last outcome category  object
#  11  Context                object
# dtypes: float64(2), object(10)
# memory usage: 277.8+ MB

# %%
allData
# Out:
#                                                   Crime ID    Month  \
# 0                                                      NaN  2010-12
# 1                                                      NaN  2010-12
# 2                                                      NaN  2010-12
# 3                                                      NaN  2010-12
# 4                                                      NaN  2010-12
# ...                                                    ...      ...
# 3034424  96ed99cdd2509211745e4784494d20cabda74c5fc9ea73...  2019-06
# 3034425  a741552a5306348b1218fcf651363b54200211a07af773...  2019-06
# 3034426  75e215f9c8c9bf1bfde169cf5f2c15d44dc65361e5a4a4...  2019-06
# 3034427  63213367c7abb33ee6a30d67cc93296c5633efbc85fb41...  2019-06
# 3034428  8b255ebd4e7f62f0a5960a027712e1681fea82bd8a1e95...  2019-06
#
#                        Reported by               Falls within  Longitude  \
# 0        Greater Manchester Police  Greater Manchester Police  -2.392346
# ...

# %%
allData.to_pickle('Manchester_street.pickle')

# %%
df = pd.read_pickle('Manchester_street.pickle')

# %%
df
# Out:
#                                                   Crime ID    Month  \
# 0                                                      NaN  2010-12
# 1                                                      NaN  2010-12
# 2                                                      NaN  2010-12
# 3                                                      NaN  2010-12
# 4                                                      NaN  2010-12
# ...                                                    ...      ...
# 3034424  96ed99cdd2509211745e4784494d20cabda74c5fc9ea73...  2019-06
# 3034425  a741552a5306348b1218fcf651363b54200211a07af773...  2019-06
# 3034426  75e215f9c8c9bf1bfde169cf5f2c15d44dc65361e5a4a4...  2019-06
# 3034427  63213367c7abb33ee6a30d67cc93296c5633efbc85fb41...  2019-06
# 3034428  8b255ebd4e7f62f0a5960a027712e1681fea82bd8a1e95...  2019-06
#
#                        Reported by               Falls within  Longitude  \
# 0        Greater Manchester Police  Greater Manchester Police  -2.392346
# ...
